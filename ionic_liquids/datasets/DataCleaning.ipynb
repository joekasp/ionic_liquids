# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("inputdata.xlsx")

# %%
data['EC_value'], data['EC_error'] = zip(*data['ELE_COD'].map(lambda x: x.split('±')))

# %%
data
# Out:
#        NUM                                   A  B  MOLFRC(for A and B)  \
# 0        1    [O-]S(=O)(=O)C.c1c[n+](cn1CCCC)C  O                0.004
# 1        2    [O-]S(=O)(=O)C.c1c[n+](cn2CCCC)C  O                0.004
# 2        3    [O-]S(=O)(=O)C.c1c[n+](cn3CCCC)C  O                0.004
# 3        4    [O-]S(=O)(=O)C.c1c[n+](cn4CCCC)C  O                0.004
# 4        5    [O-]S(=O)(=O)C.c1c[n+](cn5CCCC)C  O                0.004
# 5        6    [O-]S(=O)(=O)C.c1c[n+](cn6CCCC)C  O                0.004
# 6        7    [O-]S(=O)(=O)C.c1c[n+](cn7CCCC)C  O                0.004
# 7        8    [O-]S(=O)(=O)C.c1c[n+](cn8CCCC)C  O                0.004
# 8        9    [O-]S(=O)(=O)C.c1c[n+](cn9CCCC)C  O                0.004
# 9       10   [O-]S(=O)(=O)C.c1c[n+](cn10CCCC)C  O                0.004
# 10      11   [O-]S(=O)(=O)C.c1c[n+](cn11CCCC)C  O                0.004
# 11      12   [O-]S(=O)(=O)C.c1c[n+](cn12CCCC)C  O                0.004
# ...
