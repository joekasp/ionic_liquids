# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def get_data(t=5):
    x_range = np.arange(20)
    y_vals = np.ones(20) + t * x_range + np.random.random(20)
    return x_range,y_vals

# %%
def temp_slider(t,cmpd_1,cmpd_2):
    print("Temperature is: ",t)
    print("Compound A is: ",cmpd_1)
    print("Compound B is: ",cmpd_2)
    x,y = get_data(t)
    plt.plot(x,y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    
#interact_manual(temp_slider,t=298,x=['apples','oranges'])
mol_list = ['methanol','water']
interact(temp_slider,t=298,cmpd_1=mol_list,cmpd_2=mol_list)
# Out:
# Temperature is:  471
# Compound A is:  methanol
# Compound B is:  methanol

# %%
np.random.random(20)
# Out:
# array([ 0.33106545,  0.97098537,  0.78045041,  0.14794585,  0.84788   ,
#         0.69086289,  0.25672211,  0.52965324,  0.93869434,  0.77940317,
#         0.74205991,  0.08041714,  0.30043783,  0.71424766,  0.5189157 ,
#         0.71338244,  0.98354821,  0.17662466,  0.9487519 ,  0.55346078])
